# %% [markdown]
# For installing and importing tweepy Python 3.7
# https://stackoverflow.com/questions/49781303/tweepy-wont-import-to-jupyter-notebook-on-azure

# %%
# !pip install tweepy
# !pip install pandas

# %%
## Import modules
import tweepy
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
from tweepy import Stream

## Import packages
import numpy as np
import pandas as pd
import csv

## Set up keys
CONSUMER_KEY = 'cLIFNFcszEpqtr1BjgYy7EhJk '
CONSUMER_SECRET = 'HSPT1KQCq6LpKdFEjqXy2J0ixgSxicvZZs6nxCA9nHeJnMyZTB'
ACCESS_KEY = '749560820-et4N6j2dhzoL5dXapCzCqsruTjTgjVHyEHB4riP0'
ACCESS_SECRET = '303l01XhiQdyXHnS8EyQSp6mWDHZEa6pOsKzWHAQZ14R1'

auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY, ACCESS_SECRET)

# Create API object to access Twitter
api = tweepy.API(auth)

# %%
# Check API object was created
print(api)

# %%
# Inherits from StreamListener
class StdOutListener(StreamListener):
    
    #Override
    def on_data(self, data):
        print(data)
        return True
    
    #Override, print out status message for error
    def on_error(self,status):
        print(status)

# %%
# Load CSV file with news articles 2015-date
dat = pd.read_csv("Articles.csv")
dat.head(5)
# Out:
#                                              Article      Date  \
# 0  KARACHI: The Sindh government has decided to b...  1/1/2015
# 1  HONG KONG: Asian markets started 2015 on an up...  1/2/2015
# 2  HONG KONG:  Hong Kong shares opened 0.66 perce...  1/5/2015
# 3  HONG KONG: Asian markets tumbled Tuesday follo...  1/6/2015
# 4  NEW YORK: US oil prices Monday slipped below $...  1/6/2015
#
#                                              Heading  NewsType
# 0  sindh govt decides to cut public transport far...  business
# 1                    asia stocks up in new year trad  business
# 2           hong kong stocks open 0.66 percent lower  business
# 3             asian stocks sink euro near nine year   business
# 4                 us oil prices slip below 50 a barr  business

# %%
## Show dataframe of articles published in New York
df = pd.DataFrame(dat)
df[df['Article'].str.contains("NEW|YORK")==True]
# Out:
#                                                 Article        Date  \
# 4     NEW YORK: US oil prices Monday slipped below $...    1/6/2015
# 29    NEW YORK: US authorities are investigating the...    2/2/2015
# 68    NEW YORK: Billionaire philanthropist Bill Gate...    3/3/2015
# 103   NEW YORK: Crude-oil prices fell Thursday after...    4/3/2015
# 188   NEW YORK: Oil prices rose modestly on Monday a...   6/23/2015
# 203   NEW YORK: The euro gained ground on Wednesday ...    7/9/2015
# 207   NEW YORK: The euro surged against the dollar F...   7/11/2015
# 209   NEW YORK: Oil prices slipped Monday as traders...   7/14/2015
# 233   NEW YORK: The New York Times said Thursday its...    8/6/2015
# 262   NEW YORK: Pakistani Ambassador to the United N...   8/28/2015
# 411   strong>NEW YORK/LONDON: Oil prices rose on Thu...    1/1/2016
# 435   NEW DELHI: Indian Prime Minister Narendra Modi...   1/16/2016
# 442   strong>MANILA: Gold edged higher on Wednesday ...   1/20/2016
# ...

# %% [markdown]
# ## Google Search

# %%
# Read in World Cup search interest over 2018 year
#  Number 1 most searched
dat_1 = pd.read_csv("Data/Google_Top_Search_2018/Interest/World_Cup.csv")
dat_1.head()
# Out:
#               Category: All categories
# Week        World Cup: (United States)
# 2018-01-07                           1
# 2018-01-14                           1
# 2018-01-21                           1
# 2018-01-28                           1

# %%
# Read in Hurricane Florence search interest over 2018 year
# Number 2 most searched

dat_2 = pd.read_csv("Data/Google_Top_Search_2018/Interest/Hurricane_Florence.csv")
dat_2.head()
# Out:
#                        Category: All categories
# Week        Hurricane Florence: (United States)
# 2018-01-07                                   <1
# 2018-01-14                                    0
# 2018-01-21                                    0
# 2018-01-28                                   <1

# %% [markdown]
# https://chrisalbon.com/python/data_wrangling/pandas_join_merge_dataframe/

# %%
## Read in CSV files for the top 10 Google searches of 2018

dat_3 = pd.read_csv("Data/Google_Top_Search_2018/Interest/Mac_Miller.csv")
dat_3.head()
# Out:
#                Category: All categories
# Week        Mac Miller: (United States)
# 2018-01-07                           <1
# 2018-01-14                           <1
# 2018-01-21                           <1
# 2018-01-28                           <1

# %%
# Concat all dataframes
df_1 = pd.DataFrame(dat_1)
df_2 = pd.DataFrame(dat_2)
df_3 = pd.DataFrame(dat_3)
df_concat = pd.concat([df_1, df_2], axis=1)
df_concat
# Out:
#               Category: All categories             Category: All categories
# Week        World Cup: (United States)  Hurricane Florence: (United States)
# 2018-01-07                           1                                   <1
# 2018-01-14                           1                                    0
# 2018-01-21                           1                                    0
# 2018-01-28                           1                                   <1
# 2018-02-04                           1                                    0
# 2018-02-11                           1                                   <1
# 2018-02-18                           1                                   <1
# 2018-02-25                           1                                    0
# 2018-03-04                           1                                   <1
# 2018-03-11                           1                                   <1
# ...
